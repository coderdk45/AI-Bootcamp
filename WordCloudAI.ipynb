# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Download required NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Text
text = """I enjoy exploring new technologies and building innovative software projects.
As a Full Stack Developer, I’m currently learning AI and Machine Learning to integrate
intelligent features into my applications and expand my technical skills.
I also enjoy coding, solving problems, learning new concepts, and working on projects
that help me grow toward my goal of joining a leading product-based company."""

print(text)

# Tokenization
words = word_tokenize(text.lower())

# Print words
print(words)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Deepak
# [nltk_data]     Prajapati\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Deepak
# [nltk_data]     Prajapati\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# I enjoy exploring new technologies and building innovative software projects.
# As a Full Stack Developer, I’m currently learning AI and Machine Learning to integrate
# intelligent features into my applications and expand my technical skills.
# I also enjoy coding, solving problems, learning new concepts, and working on projects
# that help me grow toward my goal of joining a leading product-based company.
# ...

# %%
text = """I enjoy exploring new technologies and building innovative software projects. As a Full Stack Developer, I’m currently learning AI and Machine Learning to integrate intelligent features into my applications and expand my technical skills. I also enjoy coding, solving problems, learning new concepts, and working on projects that help me grow toward my goal of joining a leading product-based company."""
print(text)
# Out:
# I enjoy exploring new technologies and building innovative software projects. As a Full Stack Developer, I’m currently learning AI and Machine Learning to integrate intelligent features into my applications and expand my technical skills. I also enjoy coding, solving problems, learning new concepts, and working on projects that help me grow toward my goal of joining a leading product-based company.

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))

filtered_words = [
    word for word in words
    if word.isalpha() and word not in stop_words
]

# Join words
clean_text = " ".join(filtered_words)

# Create WordCloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(clean_text)

# Display
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
